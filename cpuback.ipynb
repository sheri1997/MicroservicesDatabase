-- %% [markdown]
-- # [dbo].[AuditMessage]

-- %%
USE [MicroservicesDatabase]
GO

-- %%
/****** Object:  Table [dbo].[AuditMessage]    Script Date: 20/01/2022 4:50:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AuditMessage](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Audit_Message] [nvarchar](500) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Candidate_Bank_Details]

-- %%
/****** Object:  Table [dbo].[Candidate_Bank_Details]    Script Date: 20/01/2022 4:50:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Candidate_Bank_Details](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[candidateId] [int] NULL,
	[AccountNumberIs] [int] NOT NULL,
	[AccountNumberVerifiedIS] [int] NOT NULL,
	[IFSCCode] [int] NOT NULL,
	[is_isfc_code_verified] [varchar](4) NOT NULL,
	[pan_number] [int] NOT NULL,
	[is_pan_number_verified] [varchar](4) NOT NULL,
	[addhaar_number] [int] NOT NULL,
	[is_aadhaar_number_verified] [varchar](4) NOT NULL,
	[creator_stamp] [varchar](100) NULL,
	[creator_user] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Candidate_Documents]

-- %%
/****** Object:  Table [dbo].[Candidate_Documents]    Script Date: 20/01/2022 4:50:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Candidate_Documents](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[candidateId] [int] NULL,
	[doc_type] [varchar](10) NOT NULL,
	[doc_pathStatus] [varchar](10) NOT NULL,
	[creator_stamp] [varchar](100) NULL,
	[creator_user] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Candidate_Education_Detailed_Check]

-- %%
/****** Object:  Table [dbo].[Candidate_Education_Detailed_Check]    Script Date: 20/01/2022 4:50:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Candidate_Education_Detailed_Check](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[candidateId] [int] NULL,
	[field_name] [varchar](100) NOT NULL,
	[is_field_name_verified] [varchar](4) NOT NULL,
	[lastupd_stamp] [varchar](100) NOT NULL,
	[lastupd_stamp_user] [varchar](100) NOT NULL,
	[creator_stamp] [varchar](100) NULL,
	[creator_user] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Candidate_Qualification]

-- %%
/****** Object:  Table [dbo].[Candidate_Qualification]    Script Date: 20/01/2022 4:50:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Candidate_Qualification](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[candidateId] [int] NULL,
	[diploma] [varchar](20) NULL,
	[degree_name_is] [varchar](20) NULL,
	[degree_name_verified_is] [varchar](4) NOT NULL,
	[employee_decipline] [varchar](100) NOT NULL,
	[employee_decipline_verified] [varchar](4) NOT NULL,
	[passing_year] [int] NOT NULL,
	[is_passing_year_verified] [varchar](4) NOT NULL,
	[final_year_per] [int] NOT NULL,
	[is_final_year_per_verified] [varchar](4) NOT NULL,
	[training_institue] [varchar](50) NOT NULL,
	[is_training_institue_verified] [varchar](4) NOT NULL,
	[training_duration_month] [int] NOT NULL,
	[is_training_durationmonth_verified] [varchar](4) NOT NULL,
	[other_training] [varchar](50) NULL,
	[is_other_training_institue_verified] [varchar](4) NULL,
	[creator_stamp] [varchar](100) NULL,
	[creator_user] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Candidates_Personal_Details_Check]

-- %%
/****** Object:  Table [dbo].[Candidates_Personal_Details_Check]    Script Date: 20/01/2022 4:50:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Candidates_Personal_Details_Check](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[candidateId] [int] NULL,
	[FieldName] [varchar](100) NOT NULL,
	[IsverifiedLastupdStamp] [varchar](100) NOT NULL,
	[LastupdUser] [varchar](100) NOT NULL,
	[CreatorStamp] [varchar](100) NULL,
	[CreatorUser] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Company]

-- %%
/****** Object:  Table [dbo].[Company]    Script Date: 20/01/2022 4:50:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Company](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Company_Name] [varchar](100) NOT NULL,
	[Company_address] [varchar](500) NOT NULL,
	[Company_location] [varchar](100) NOT NULL,
	[Company_status] [varchar](100) NOT NULL,
	[creator_stamp] [varchar](100) NULL,
	[creator_user] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CPULogDatabse]

-- %%
/****** Object:  Table [dbo].[CPULogDatabse]    Script Date: 20/01/2022 4:50:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CPULogDatabse](
	[DateTime] [nvarchar](50) NOT NULL,
	[Cpu_Count] [tinyint] NOT NULL,
	[Cpu_Working_Time] [float] NOT NULL,
	[Cpu_idle_Time] [float] NOT NULL,
	[cpu_percent] [float] NOT NULL,
	[Usage_Cpu_Count] [tinyint] NOT NULL,
	[number_of_software_interrupts_since_boot] [int] NOT NULL,
	[number_of_system_calls_since_boot] [tinyint] NOT NULL,
	[number_of_interrupts_since_boot] [int] NOT NULL,
	[cpu_avg_load_over_1_min] [float] NOT NULL,
	[cpu_avg_load_over_5_min] [float] NOT NULL,
	[cpu_avg_load_over_15_min] [float] NOT NULL,
	[system_total_memory] [bigint] NOT NULL,
	[system_used_memory] [bigint] NOT NULL,
	[system_free_memory] [bigint] NOT NULL,
	[system_active_memory] [bigint] NOT NULL,
	[system_inactive_memory] [bigint] NOT NULL,
	[system_buffers_memory] [bigint] NOT NULL,
	[system_cached_memory] [bigint] NOT NULL,
	[system_shared_memory] [int] NOT NULL,
	[system_avalible_memory] [bigint] NOT NULL,
	[disk_total_memory] [nvarchar](50) NOT NULL,
	[disk_used_memory] [bigint] NOT NULL,
	[disk_free_memory] [nvarchar](max) NOT NULL,
	[disk_read_count] [int] NOT NULL,
	[disk_write_count] [int] NOT NULL,
	[disk_read_bytes] [bigint] NOT NULL,
	[disk_write_bytes] [bigint] NOT NULL,
	[time_spent_reading_from_disk] [int] NOT NULL,
	[time_spent_writing_to_disk] [int] NOT NULL,
	[time_spent_doing_actual_I_Os] [int] NOT NULL,
	[number_of_bytes_sent] [bigint] NOT NULL,
	[number_of_bytes_received] [bigint] NOT NULL,
	[number_of_packets_sent] [int] NOT NULL,
	[number_of_packets_recived] [int] NOT NULL,
	[total_number_of_errors_while_receiving] [tinyint] NOT NULL,
	[total_number_of_errors_while_sending] [tinyint] NOT NULL,
	[total_number_of_incoming_packets_which_were_dropped] [tinyint] NOT NULL,
	[total_number_of_outgoing_packets_which_were_dropped] [tinyint] NOT NULL,
	[boot_time] [nvarchar](50) NOT NULL,
	[user_name] [nvarchar](50) NOT NULL,
	[keyboard] [float] NOT NULL,
	[mouse] [int] NOT NULL,
	[technology] [nvarchar](50) NOT NULL,
	[files_changed] [smallint] NOT NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Fellowship_Candidates]

-- %%
/****** Object:  Table [dbo].[Fellowship_Candidates]    Script Date: 20/01/2022 4:50:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Fellowship_Candidates](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[First_Name] [varchar](100) NOT NULL,
	[Last_Name] [varchar](100) NOT NULL,
	[EmailID] [varchar](100) NULL,
	[Hired_Date] [datetime] NOT NULL,
	[Mobile_Number] [int] NOT NULL,
	[Permanent_Pincode] [int] NULL,
	[Hired_Lab] [varchar](50) NOT NULL,
	[Attitude] [varchar](100) NOT NULL,
	[Communication_Remark] [varchar](100) NOT NULL,
	[Knowledge_Remark] [varchar](100) NOT NULL,
	[Aggregate_Remark] [varchar](100) NULL,
	[Creator_Stamp] [varchar](100) NULL,
	[Creator_User] [varchar](100) NOT NULL,
	[Birth_Date] [date] NOT NULL,
	[Birth_Date_Verified] [varchar](4) NOT NULL,
	[Parent_Name] [varchar](100) NOT NULL,
	[Parent_Occupation] [varchar](100) NOT NULL,
	[Parents_Mobile_Number] [int] NOT NULL,
	[Parents_Annual_Salery] [int] NOT NULL,
	[Local_Address] [varchar](500) NOT NULL,
	[Permanent_Address] [varchar](500) NOT NULL,
	[Photo_Path] [varchar](100) NOT NULL,
	[Joining_Date] [datetime] NOT NULL,
	[Candidate_Status] [varchar](20) NOT NULL,
	[Personal_Information] [varchar](100) NULL,
	[Bank_Information] [varchar](100) NOT NULL,
	[Educational_Information] [varchar](100) NOT NULL,
	[Document_Status] [varchar](100) NOT NULL,
	[Remark] [varchar](500) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[EmailID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Mobile_Number] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Hired_Candidates]

-- %%
/****** Object:  Table [dbo].[Hired_Candidates]    Script Date: 20/01/2022 4:50:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Hired_Candidates](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[First_Name] [varchar](100) NOT NULL,
	[Last_Name] [varchar](100) NOT NULL,
	[EmailID] [varchar](100) NULL,
	[Hired_Date] [datetime] NOT NULL,
	[Mobile_Number] [int] NOT NULL,
	[Permanent_Pincode] [int] NULL,
	[Hired_Lab] [varchar](50) NOT NULL,
	[Attitude] [varchar](100) NOT NULL,
	[Communication_Remark] [varchar](100) NOT NULL,
	[Knowledge_Remark] [varchar](100) NOT NULL,
	[Aggregate_Remark] [varchar](100) NULL,
	[Creator_Stamp] [varchar](100) NULL,
	[Creator_User] [varchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[EmailID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Mobile_Number] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Maker_Program]

-- %%
/****** Object:  Table [dbo].[Maker_Program]    Script Date: 20/01/2022 4:50:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Maker_Program](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[programName] [varchar](100) NOT NULL,
	[programType] [varchar](100) NOT NULL,
	[programLink] [varchar](100) NOT NULL,
	[tech_stack_id] [int] NOT NULL,
	[tech_type_id] [int] NOT NULL,
	[is_program_approved] [varchar](100) NULL,
	[Description_program] [varchar](500) NULL,
	[Program_status] [varchar](50) NULL,
	[creator_stamp] [varchar](100) NULL,
	[creator_user] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[User_Details]

-- %%
/****** Object:  Table [dbo].[User_Details]    Script Date: 20/01/2022 4:50:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[User_Details](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[email] [varchar](100) NOT NULL,
	[first_name] [varchar](100) NOT NULL,
	[last_name] [varchar](100) NOT NULL,
	[password_user] [varchar](100) NOT NULL,
	[contact_number] [int] NOT NULL,
	[verified] [varchar](4) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[contact_number] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[User_Roles]

-- %%
/****** Object:  Table [dbo].[User_Roles]    Script Date: 20/01/2022 4:50:07 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[User_Roles](
	[Id] [int] NULL,
	[Role_name] [varchar](100) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Candidate__candi__3C69FB99]

-- %%
ALTER TABLE [dbo].[Candidate_Bank_Details]  WITH CHECK ADD FOREIGN KEY([candidateId])
REFERENCES [dbo].[Fellowship_Candidates] ([Id])
GO

-- %% [markdown]
-- # [FK__Candidate__candi__45F365D3]

-- %%
ALTER TABLE [dbo].[Candidate_Documents]  WITH CHECK ADD FOREIGN KEY([candidateId])
REFERENCES [dbo].[Fellowship_Candidates] ([Id])
GO

-- %% [markdown]
-- # [FK__Candidate__candi__4222D4EF]

-- %%
ALTER TABLE [dbo].[Candidate_Education_Detailed_Check]  WITH CHECK ADD FOREIGN KEY([candidateId])
REFERENCES [dbo].[Fellowship_Candidates] ([Id])
GO

-- %% [markdown]
-- # [FK__Candidate__candi__3F466844]

-- %%
ALTER TABLE [dbo].[Candidate_Qualification]  WITH CHECK ADD FOREIGN KEY([candidateId])
REFERENCES [dbo].[Fellowship_Candidates] ([Id])
GO

-- %% [markdown]
-- # [FK__Candidate__candi__398D8EEE]

-- %%
ALTER TABLE [dbo].[Candidates_Personal_Details_Check]  WITH CHECK ADD FOREIGN KEY([candidateId])
REFERENCES [dbo].[Fellowship_Candidates] ([Id])
GO

-- %% [markdown]
-- # [FK__User_Roles__Id__4BAC3F29]

-- %%
ALTER TABLE [dbo].[User_Roles]  WITH CHECK ADD FOREIGN KEY([Id])
REFERENCES [dbo].[User_Details] ([Id])
GO
